# %%
from scipy.stats import binom
import seaborn as sbn1

binom.rvs(size = 10, n=20, p = 0.5)
# Out:
# array([12, 10, 11, 10, 11, 12,  7,  7, 11, 14])

# %%
data = binom.rvs(n = 20, p = 0.8, size = 1000, loc =0.0)

# %%
data
# Out:
# array([18, 17, 15, 17, 16, 18, 15, 18, 18, 19, 19, 16, 14, 15, 17, 17, 16,
#        15, 15, 16, 15, 14, 17, 16, 18, 15, 17, 15, 14, 18, 13, 19, 17, 18,
#        17, 18, 17, 16, 17, 14, 18, 13, 18, 12, 15, 12, 16, 15, 17, 17, 14,
#        14, 18, 16, 16, 14, 18, 16, 18, 16, 14, 16, 15, 17, 17, 13, 14, 16,
#        15, 19, 16, 16, 16, 18, 20, 18, 20, 14, 19, 18, 17, 17, 15, 20, 16,
#        16, 16, 17, 14, 16, 17, 16, 18, 17, 14, 16, 16, 16, 18, 12, 15, 19,
#        19, 16, 15, 11, 15, 12, 17, 16, 16, 15, 19, 17, 15, 18, 15, 15, 18,
#        19, 11, 16, 15, 17, 19, 17, 17, 15, 13, 15, 13, 16, 16, 17, 13, 18,
#        16, 16, 16, 17, 16, 17, 16, 16, 15, 17, 18, 13, 17, 16, 15, 18, 16,
#        16, 17, 18, 17, 18, 12, 19, 13, 16, 18, 17, 15, 19, 16, 15, 15, 18,
#        17, 14, 16, 16, 15, 17, 14, 15, 14, 17, 18, 15, 15, 14, 17, 17, 18,
#        16, 17, 16, 18, 13, 18, 16, 16, 15, 15, 19, 16, 17, 17, 14, 20, 14,
# ...

# %%
xaxis = sbn.distplot(data, kde = True, color = 'red', hist_kws = {"linewidth":25, 'alpha':1})
xaxis.set(xlabel='Binomial Dist', ylabel = 'Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial Dist')]

# %%
from scipy.stats import poisson
data_poi = poisson.rvs(mu=4, size = 1000)

# %%
data_poi
# Out:
# array([ 4,  5,  3,  1,  5,  5,  6,  1,  7,  4,  6,  4,  3,  7,  3,  8,  6,
#         9,  5,  6,  4,  5,  5,  2,  2,  1,  6,  5,  8,  4,  5,  6,  4,  3,
#         3,  8,  1,  6,  2,  2,  3,  8,  5,  4,  4,  4,  4,  7,  1,  5,  6,
#         5,  7,  5,  4,  3,  1,  4,  4,  3,  6,  2,  8,  3,  7,  4,  8,  1,
#         3,  3,  2,  6,  4,  1,  5,  2,  5,  5,  1,  2,  7,  6,  4,  2,  0,
#         6,  5,  4,  7,  2,  4,  3,  3,  5,  3,  4,  2,  3,  3,  2,  5,  6,
#         4,  1,  3,  5,  4,  2,  6,  2,  7,  4,  4,  1,  8,  5,  3,  6,  5,
#         4,  3,  4,  5,  1,  5,  8,  5,  0,  9,  2,  6,  4,  4,  5,  1,  3,
#         2,  5,  2,  4,  6,  4,  4,  9,  5,  6,  7,  6,  3,  0,  2,  6,  4,
#         4,  2,  7,  5,  3,  7,  5,  2,  4,  4,  0,  4,  6,  3,  1,  2,  5,
#         5,  6,  8,  6,  4,  1,  3,  4,  4,  3,  3,  3,  5,  2,  5,  3,  4,
#         5,  3,  2,  5,  5,  4,  4,  0,  3,  2,  5,  1,  3,  3,  3,  6,  2,
# ...

# %%
xaxis = sbn.distplot(data_poi, kde = True, color = 'blue', hist_kws = {"linewidth":25, 'alpha':1})
xaxis.set(xlabel='Poisson Dist', ylabel = 'Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Dist')]

# %%
import matplotlib.pyplot as plt
import numpy as np

# unit area ellipse
rx, ry = 3., 1.
area = rx * ry * np.pi
theta = np.arange(0, 2 * np.pi + 0.01, 0.1)
verts = np.column_stack([rx / area * np.cos(theta), ry / area * np.sin(theta)])

x, y, s, c = np.random.rand(4, 30)
s *= 10**2.

fig, ax = plt.subplots()
ax.scatter(x, y, s, c, marker=verts)

plt.show()

# %%
import seaborn as sns
sns.set()

# Load the example iris dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="distance", y="orbital_period",
                     hue="year", size="mass",
                     palette=cmap, sizes=(10, 200),
                     data=planets)
